# %% [markdown]
# # YOLOv8 Object Tracking

# %% [markdown]
# ## Ortam Hazırlığı

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/YOLOv8/3_obj_tracking_and_counting
# Out:
# /content/drive/MyDrive/YOLOv8/3_obj_tracking_and_counting

# %%
# %pip install ultralytics

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.184 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %% [markdown]
# ## Test // Tracking

# %% [markdown]
# Önceden eğitilmiş (pre-trained model) model ile nesne takibi:

# %%
# !yolo track model=yolov8n.pt source="data/test.mp4"

# %%
# !yolo track model=yolov8n.pt source="data/test.mp4" tracker="bytetrack.yaml" # Byte-Track, BoT-Track

# %% [markdown]
# Özgün model ile nesne takibi:

# %%
# !yolo track model="custom_model_path" source="data/test.mp4" tracker="custom_tracker.yaml" # Byte-Track, BoT-Track
