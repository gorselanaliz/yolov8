# %% [markdown]
# Mounting Drive

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd /content/drive/MyDrive/YOLO/yolov10-project
# Out:
# /content/drive/MyDrive/YOLO/yolov10-project

# %% [markdown]
# Installing Libraries

# %%
# !pip install -q roboflow
# !pip install -q git+https://github.com/THU-MIG/yolov10.git
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 8.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 10.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 19.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.0 MB/s eta 0:00:00
# WARNING: The candidate selected for download or install is a yanked version: 'opencv-python-headless' candidate (version 4.8.0.74 at https://files.pythonhosted.org/packages/76/02/f128517f3ade4bb5f71e2afd8461dba70e3f466ce745fa1fd1fade9ad1b7/opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from https://pypi.org/simple/opencv-python-headless/) (requires-python:>=3.6))
# Reason for being yanked: deprecated, use 4.8.0.76
# ...

# %%
# %cd /content/drive/MyDrive/YOLO/yolov10-project/yolov10
# Out:
# /content/drive/MyDrive/YOLO/yolov10-project/yolov10

# %%
# !mkdir datasets
# !mkdir models

# %cd models
# Out:
# /content/drive/MyDrive/YOLO/yolov10-project/yolov10/models

# %%
# !wget https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt
# !wget https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt
# !wget https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10s.pt
# !wget https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10m.pt
# !wget https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10b.pt
# !wget https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10x.pt
# !wget https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10l.pt
# Out:
# --2024-06-14 09:27:51--  https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/THU-MIG/yolov10/releases/download/v1.0/yolov10n.pt [following]
# --2024-06-14 09:27:51--  https://github.com/THU-MIG/yolov10/releases/download/v1.0/yolov10n.pt
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/YOLO/yolov10-project

# %% [markdown]
# Prediction

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/YOLO/yolov10-project/yolov10'

# %% [markdown]
# Images

# %%
# !yolo predict model=models/yolov10l.pt source= "https://ultralytics.com/images/bus.jpg"
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv10l summary (fused): 461 layers, 25839728 parameters, 148320 gradients, 127.0 GFLOPs
#
# ...
# 100% 476k/476k [00:00<00:00, 29.3MB/s]
# image 1/1 /content/drive/MyDrive/YOLO/yolov10-project/yolov10/bus.jpg: 640x480 4 0s, 1 1, 1 5, 128.6ms
# Speed: 26.4ms preprocess, 128.6ms inference, 399.4ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# Videos / Webcam

# %%
# !yolo predict model=models/yolov10l.pt source= "....mp4"

# %%
# !yolo predict model=models/yolov10l.pt source= 0

# %% [markdown]
# Roboflow Dataset

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/YOLO/yolov10-project/yolov10'

# %%
# %cd /content/drive/MyDrive/YOLO/yolov10-project/yolov10/datasets
# Out:
# /content/drive/MyDrive/YOLO/yolov10-project/yolov10/datasets

# %%
# https://universe.roboflow.com/workspace-hyza2/brain-tumor-detection-6n4sk/dataset/1#

from roboflow import Roboflow
rf = Roboflow(api_key="Pi6Ttsdr7mFmgWgnjFdp")
project = rf.workspace("workspace-hyza2").project("brain-tumor-detection-6n4sk")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.1.34, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to Brain-tumor-detection-1 in yolov8:: 100%|██████████| 128/128 [00:00<00:00, 161.63it/s]

# %% [markdown]
# Training

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/YOLO/yolov10-project/yolov10

# %%
# !yolo detect train epochs=50 batch=32 plots=True model="models/yolov10n.pt" data="datasets/Brain-tumor-detection-1/data.yaml"
# Out:
# New https://pypi.org/project/ultralytics/8.2.32 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo detect train epochs=50 batch=8 plots=True model="models/yolov10l.pt" data="datasets/Brain-tumor-detection-1/data.yaml"
# Out:
# New https://pypi.org/project/ultralytics/8.2.32 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# Results

# %%
from IPython.display import Image
Image(filename="runs/detect/train2/results.png", width=600)

# %%
from IPython.display import Image
Image(filename="runs/detect/train3/results.png", width=600)

# %%
from IPython.display import Image
Image(filename="runs/detect/train5/results.png", width=600)

# %% [markdown]
# Prediction | Custom Model

# %%
# !yolo predict model = runs/detect/train5/weights/best.pt source= datasets/Brain-tumor-detection-1/test/images
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv10l summary (fused): 461 layers, 25717910 parameters, 0 gradients, 126.3 GFLOPs
#
# image 1/6 /content/drive/MyDrive/YOLO/yolov10-project/yolov10/datasets/Brain-tumor-detection-1/test/images/y10_jpg.rf.663d49dbc423acb518434ce1997f20b4.jpg: 640x640 (no detections), 55.4ms
# image 2/6 /content/drive/MyDrive/YOLO/yolov10-project/yolov10/datasets/Brain-tumor-detection-1/test/images/y2_jpg.rf.2b9dfc81a87b96c623e9c4c13e4dd182.jpg: 640x640 1 tumor, 55.5ms
# image 3/6 /content/drive/MyDrive/YOLO/yolov10-project/yolov10/datasets/Brain-tumor-detection-1/test/images/y35_jpg.rf.e8368e8b67ee2382c514cd68a49ea626.jpg: 640x640 (no detections), 55.5ms
# image 4/6 /content/drive/MyDrive/YOLO/yolov10-project/yolov10/datasets/Brain-tumor-detection-1/test/images/y43_jpg.rf.7219d25ce72cff348ec502ab354e8da9.jpg: 640x640 (no detections), 55.4ms
# ...

# %%
# video path !
# !yolo predict model = runs/detect/train3/weights/best.pt source= "...mp4"

# %%
# don't run this cell on Colab, it's for webcam!
# !yolo predict model = runs/detect/train3/weights/best.pt source= 0
